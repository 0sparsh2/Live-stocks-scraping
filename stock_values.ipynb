# %% [markdown]
# <a href="https://colab.research.google.com/github/0sparsh2/Live-stocks-scraping/blob/main/stock_values.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Nifty50

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %%
stocks_url = 'https://economictimes.indiatimes.com/indices/nifty_50_companies'
stocks_response = requests.get(stocks_url)
stock_soup = BeautifulSoup(stocks_response.text.encode('utf-8'), 'html.parser')

# %%
details = stock_soup.find_all('div', {'class': 'dataList'})

# %%
x = stock_soup.find('div', {'class' : 'headers'})

# %%
headings_column = [item.text for item in x.find('ul').find_all('li')]
len(headings_column)
# Out:
# 11

# %%
all_lists = []
for stock in details:
  lists = stock.find_all('li')
  all_lists.append([item.text for item in lists])

for list_vals in all_lists:
  list_vals[0] = list_vals[0][1:]

# %%
nifty50 = pd.DataFrame(all_lists,columns=headings_column)

# %%
nifty50
# Out:
#         Company Name       LTP  ... Past 365 Day's Trend 365 Day's % Chg
# 0           Hindalco    525.80  ...                               100.80
# 1         Divis Labs   4355.70  ...                                18.40
# 2               ONGC    170.05  ...                                74.14
# 3     UltraTech Cem.   7483.10  ...                                21.03
# 4         Tata Steel   1183.50  ...                                80.43
# 5          JSW Steel    661.95  ...                                65.36
# 6                L&T   1954.00  ...                                27.73
# 7         Sun Pharma    892.50  ...                                41.33
# 8      Bajaj Finance   7166.70  ...                                30.19
# 9       Asian Paints   3227.95  ...                                34.40
# 10      Grasim Inds.   1745.35  ...                                46.85
# 11         HDFC Bank   1524.55  ...                                -3.45
# ...

# %% [markdown]
# #Nifty Next 50

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %%
stocks_url = 'https://economictimes.indiatimes.com/markets/nifty-next-50/indexsummary/indexid-2346,exchange-50.cms'
stocks_response = requests.get(stocks_url)
stock_soup = BeautifulSoup(stocks_response.text.encode('utf-8'), 'html.parser')

# %%
details = stock_soup.find_all('div', {'class': 'dataList'})

# %%
x = stock_soup.find('div', {'class' : 'headers'})

# %%
headings_column = [item.text for item in x.find('ul').find_all('li')]
len(headings_column)
# Out:
# 11

# %%
all_lists = []
for stock in details:
  lists = stock.find_all('li')
  all_lists.append([item.text for item in lists])

for list_vals in all_lists:
  list_vals[0] = list_vals[0][1:]

# %%
niftynext50 = pd.DataFrame(all_lists,columns=headings_column)

# %%
niftynext50
# Out:
#           Company Name       LTP  ... Past 365 Day's Trend 365 Day's % Chg
# 0    Chola Inv Finance    675.70  ...                                45.50
# 1             Vedanta     356.35  ...                               102.01
# 2        PI Industries   2552.20  ...                                13.35
# 3          Dabur India    569.00  ...                                 8.15
# 4          Adani Green   1950.35  ...                                80.92
# 5             YES Bank     13.70  ...                               -15.43
# 6                  P&G  15119.00  ...                                22.99
# 7               Marico    510.55  ...                                23.32
# 8           InterGlobe   1974.35  ...                                18.06
# 9                 JSPL    424.40  ...                                47.16
# 10        L&T Infotech   6282.00  ...                                45.97
# ...
